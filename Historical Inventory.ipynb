# %%
import pandas as pd

# read csvs (skip first 6 rows)
jan2022 = pd.read_csv('Historical Inventory - 2022-01-01.csv',skiprows=6)
feb2022 = pd.read_csv('Historical Inventory - 2022-02-01.csv',skiprows=6)
mar2022 = pd.read_csv('Historical Inventory - 2022-03-01.csv',skiprows=6)
apr2022 = pd.read_csv('Historical Inventory - 2022-04-01.csv',skiprows=6)
may2022 = pd.read_csv('Historical Inventory - 2022-05-01.csv',skiprows=6)
jun2022 = pd.read_csv('Historical Inventory - 2022-06-01.csv',skiprows=6)
jul2022 = pd.read_csv('Historical Inventory - 2022-07-01.csv',skiprows=6)
aug2022 = pd.read_csv('Historical Inventory - 2022-08-01.csv',skiprows=6)
sep2022 = pd.read_csv('Historical Inventory - 2022-09-01.csv',skiprows=6)
oct2022 = pd.read_csv('Historical Inventory - 2022-10-01.csv',skiprows=6)
nov2022 = pd.read_csv('Historical Inventory - 2022-11-01.csv',skiprows=6)
dec2022 = pd.read_csv('Historical Inventory - 2022-12-01.csv',skiprows=6)
jan2023 = pd.read_csv('Historical Inventory - 2023-01-01.csv',skiprows=6)
feb2023 = pd.read_csv('Historical Inventory - 2023-02-01.csv',skiprows=6)
mar2023 = pd.read_csv('Historical Inventory - 2023-03-01.csv',skiprows=6)
apr2023 = pd.read_csv('Historical Inventory - 2023-04-01.csv',skiprows=6)
may2023 = pd.read_csv('Historical Inventory - 2023-05-01.csv',skiprows=6)
jun2023 = pd.read_csv('Historical Inventory - 2023-06-01.csv',skiprows=6)
jul2023 = pd.read_csv('Historical Inventory - 2023-07-01.csv',skiprows=6)
aug2023 = pd.read_csv('Historical Inventory - 2023-08-01.csv',skiprows=6)
sep2023 = pd.read_csv('Historical Inventory - 2023-09-01.csv',skiprows=6)
oct2023 = pd.read_csv('Historical Inventory - 2023-10-01.csv',skiprows=6)
nov2023 = pd.read_csv('Historical Inventory - 2023-11-01.csv',skiprows=6)
dec2023 = pd.read_csv('Historical Inventory - 2023-12-01.csv',skiprows=6)
jan2024 = pd.read_csv('Historical Inventory - 2024-01-01.csv',skiprows=6)
feb2024 = pd.read_csv('Historical Inventory - 2024-02-01.csv',skiprows=6)
mar2024 = pd.read_csv('Historical Inventory - 2024-03-01.csv',skiprows=6)
apr2024 = pd.read_csv('Historical Inventory - 2024-04-01.csv',skiprows=6)
may2024 = pd.read_csv('Historical Inventory - 2024-05-01.csv',skiprows=6)
jun2024 = pd.read_csv('Historical Inventory - 2024-06-01.csv',skiprows=6)
jul2024 = pd.read_csv('Historical Inventory - 2024-07-01.csv',skiprows=6)
aug2024 = pd.read_csv('Historical Inventory - 2024-08-01.csv',skiprows=6)
sep2024 = pd.read_csv('Historical Inventory - 2024-09-01.csv',skiprows=6)
oct2024 = pd.read_csv('Historical Inventory - 2024-10-01.csv',skiprows=6)
nov2024 = pd.read_csv('Historical Inventory - 2024-11-01.csv',skiprows=6)
dec2024 = pd.read_csv('Historical Inventory - 2024-12-01.csv',skiprows=6)
jan2025 = pd.read_csv('Historical Inventory - 2025-01-01.csv',skiprows=6)
feb2025 = pd.read_csv('Historical Inventory - 2025-02-01.csv',skiprows=6)
mar2025 = pd.read_csv('Historical Inventory - 2025-03-01.csv',skiprows=6)
apr2025 = pd.read_csv('Historical Inventory - 2025-04-01.csv',skiprows=6)
may2025 = pd.read_csv('Historical Inventory - 2025-05-01.csv',skiprows=6)
jun2025 = pd.read_csv('Historical Inventory - 2025-06-01.csv',skiprows=6)
# jul2025 = pd.read_csv('Historical Inventory - 2025-07-01.csv',skiprows=6)
# aug2025 = pd.read_csv('Historical Inventory - 2025-08-01.csv',skiprows=6)
# sep2025 = pd.read_csv('Historical Inventory - 2025-09-01.csv',skiprows=6)
# oct2025 = pd.read_csv('Historical Inventory - 2025-10-01.csv',skiprows=6)
# nov2025 = pd.read_csv('Historical Inventory - 2025-11-01.csv',skiprows=6)
# dec2025 = pd.read_csv('Historical Inventory - 2025-12-01.csv',skiprows=6)

# establish Date column using the Series function
jan2022['Date'] = pd.Series(['2022-01-01'] * len(jan2022))
feb2022['Date'] = pd.Series(['2022-02-01'] * len(feb2022))
mar2022['Date'] = pd.Series(['2022-03-01'] * len(mar2022))
apr2022['Date'] = pd.Series(['2022-04-01'] * len(apr2022))
may2022['Date'] = pd.Series(['2022-05-01'] * len(may2022))
jun2022['Date'] = pd.Series(['2022-06-01'] * len(jun2022))
jul2022['Date'] = pd.Series(['2022-07-01'] * len(jul2022))
aug2022['Date'] = pd.Series(['2022-08-01'] * len(aug2022))
sep2022['Date'] = pd.Series(['2022-09-01'] * len(sep2022))
oct2022['Date'] = pd.Series(['2022-10-01'] * len(oct2022))
nov2022['Date'] = pd.Series(['2022-11-01'] * len(nov2022))
dec2022['Date'] = pd.Series(['2022-12-01'] * len(dec2022))
jan2023['Date'] = pd.Series(['2023-01-01'] * len(jan2023))
feb2023['Date'] = pd.Series(['2023-02-01'] * len(feb2023))
mar2023['Date'] = pd.Series(['2023-03-01'] * len(mar2023))
apr2023['Date'] = pd.Series(['2023-04-01'] * len(apr2023))
may2023['Date'] = pd.Series(['2023-05-01'] * len(may2023))
jun2023['Date'] = pd.Series(['2023-06-01'] * len(jun2023))
jul2023['Date'] = pd.Series(['2023-07-01'] * len(jul2023))
aug2023['Date'] = pd.Series(['2023-08-01'] * len(aug2023))
sep2023['Date'] = pd.Series(['2023-09-01'] * len(sep2023))
oct2023['Date'] = pd.Series(['2023-10-01'] * len(oct2023))
nov2023['Date'] = pd.Series(['2023-11-01'] * len(nov2023))
dec2023['Date'] = pd.Series(['2023-12-01'] * len(dec2023))
jan2024['Date'] = pd.Series(['2024-01-01'] * len(jan2024))
feb2024['Date'] = pd.Series(['2024-02-01'] * len(feb2024))
mar2024['Date'] = pd.Series(['2024-03-01'] * len(mar2024))
apr2024['Date'] = pd.Series(['2024-04-01'] * len(apr2024))
may2024['Date'] = pd.Series(['2024-05-01'] * len(may2024))
jun2024['Date'] = pd.Series(['2024-06-01'] * len(jun2024))
jul2024['Date'] = pd.Series(['2024-07-01'] * len(jul2024))
aug2024['Date'] = pd.Series(['2024-08-01'] * len(aug2024))
sep2024['Date'] = pd.Series(['2024-09-01'] * len(sep2024))
oct2024['Date'] = pd.Series(['2024-10-01'] * len(oct2024))
nov2024['Date'] = pd.Series(['2024-11-01'] * len(nov2024))
dec2024['Date'] = pd.Series(['2024-12-01'] * len(dec2024))
jan2025['Date'] = pd.Series(['2025-01-01'] * len(jan2024))
feb2025['Date'] = pd.Series(['2025-02-01'] * len(feb2024))
mar2025['Date'] = pd.Series(['2025-03-01'] * len(mar2024))
apr2025['Date'] = pd.Series(['2025-04-01'] * len(apr2024))
may2025['Date'] = pd.Series(['2025-05-01'] * len(may2024))
jun2025['Date'] = pd.Series(['2025-06-01'] * len(jun2024))
# jul2025['Date'] = pd.Series(['2025-07-01'] * len(jul2024))
# aug2025['Date'] = pd.Series(['2025-08-01'] * len(aug2024))
# sep2025['Date'] = pd.Series(['2025-09-01'] * len(sep2024))
# oct2025['Date'] = pd.Series(['2025-10-01'] * len(oct2024))
# nov2025['Date'] = pd.Series(['2025-11-01'] * len(nov2024))
# dec2025['Date'] = pd.Series(['2025-12-01'] * len(dec2024))

# concat into a single df for each year
inv2022 = pd.concat([jan2022, feb2022, mar2022, apr2022, may2022, jun2022, jul2022, aug2022, sep2022, oct2022, nov2022, dec2022])
inv2023 = pd.concat([jan2023, feb2023, mar2023, apr2023, may2023, jun2023, jul2023, aug2023, sep2023, oct2023, nov2023, dec2023])
inv2024 = pd.concat([jan2024, feb2024, mar2024, apr2024, may2024, jun2024, jul2024, aug2024, sep2024, oct2024, nov2024, dec2024])
inv2025 = pd.concat([jan2025, feb2025, mar2025, apr2025, may2025, jun2025])

# concat into a single dataset 
hist_inv = pd.concat([inv2022, inv2023, inv2024, inv2025])
hist_inv.rename({'Name ':'Item'},axis=1,inplace=True)

# remove trailing spaces from column names
hist_inv.columns = hist_inv.columns.str.strip()

# set Inv. Value to float and Rename to $ Amount of Available Inventory
hist_inv['Inv. Value'] = hist_inv['Inv. Value'].str.replace(',','')
hist_inv['Inv. Value'] = hist_inv['Inv. Value'].str.replace('$','')
hist_inv['Inv. Value'] = hist_inv['Inv. Value'].str.replace('(','-')
hist_inv['Inv. Value'] = hist_inv['Inv. Value'].str.replace(')','')
hist_inv['Inv. Value'] = hist_inv['Inv. Value'].fillna(0)
hist_inv['Inv. Value'] = hist_inv['Inv. Value'].astype(float)
hist_inv.rename({'Inv. Value':'$ Amount of Available Inventory'},axis=1,inplace=True)

# set On Hand column to integer
hist_inv['On Hand'] = hist_inv['On Hand'].str.replace(',','')
hist_inv['On Hand'] = hist_inv['On Hand'].fillna(0)
hist_inv['On Hand'] = hist_inv['On Hand'].astype(int)

# filter for On Hand Quantity > 0 and isn't in Transit
hist_inv = hist_inv[hist_inv['On Hand'] > 0]
#hist_inv = hist_inv[hist_inv['Location'] != 'Transit']

# set index to Item and save to CSV for Domo CSV Workbench
hist_inv.set_index('Item',inplace=True)
hist_inv.to_csv('Historical Inventory (New).csv')

hist_inv.tail()
# Out:
#                                 Location                     Display Name  \
# Item
# RP 95999                           BPUT4          6009 Main Body Assembly
# RP CS COMP                         BPUT2              Compensation Bundle
# RP CS Comp E-S                     BPUT2     Compensation Bundle E-Series
# RP Retrieval Kit Conveyable        BPUT2      RP Retrieval Kit Conveyable
# RP Retrieval Kit Non-Conveyable    BPUT2  RP Retrieval Kit Non-Conveyable
#
#                                 Item: Item Status Factory Product Group  \
# Item
# RP 95999                                   Active     NaN         Parts
# RP CS COMP                                 Active     NaN         Parts
# RP CS Comp E-S                             Active     NaN         Parts
# RP Retrieval Kit Conveyable                Active     NaN         Parts
# RP Retrieval Kit Non-Conveyable            Active     NaN         Parts
#
#                                  Item: PKG WEIGHT LBS  \
# Item
# ...

# %%
hist_inv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85392 entries, 1131 to RP CS Comp E-S
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Location              85392 non-null  object
#  1   Display Name          85392 non-null  object
#  2   Item: Item Status     36030 non-null  object
#  3   Factory               82903 non-null  object
#  4   Product Group         85357 non-null  object
#  5   Item: PKG WEIGHT LBS  47265 non-null  float64
#  6   Inv. Value            85392 non-null  object
#  7   % of Inv. Value       85392 non-null  object
#  8   On Hand               85392 non-null  int32
#  9   Date                  85392 non-null  object
# dtypes: float64(1), int32(1), object(8)
# memory usage: 6.8+ MB
